# %%
import pandas as pd
import numpy as np

# %%
cite_fake = pd.read_csv("./Processed_data/Cite_fake_New.csv")

# %%
cite_fake.groupby(["Paper Type"]).count()
# Out:
#              TitleID  Authors  Title  Source title  Proceeding  Volume  \
# Paper Type
# Demo Paper       216      216    216           216         127      65
# Full Paper       293      293    293           293         172      86
# Poster           188      188    188           188         173       0
# Short Paper      193      193    193           193          96      82
#
#              Paper Area  Type  Conference Type  Approval  Chair_or_Editor1  \
# Paper Type
# Demo Paper          216   216              146       216               216
# Full Paper          293   293              199       293               293
# Poster              188   188              188       188               188
# Short Paper         193   193              105       193               193
#
#              Chair_or_Editor2
# Paper Type
# Demo Paper                216
# Full Paper                293
# Poster                    188
# Short Paper               193

# %%
cite_fake.groupby(["Type"]).count()
# Out:
#             TitleID  Authors  Title  Source title  Proceeding  Volume  \
# Type
# Conference      638      638    638           638         568       0
# Journal         252      252    252           252           0     233
#
#             Paper Area  Conference Type  Paper Type  Approval  \
# Type
# Conference         638              638         638       638
# Journal            252                0         252       252
#
#             Chair_or_Editor1  Chair_or_Editor2
# Type
# Conference               638               638
# Journal                  252               252

# %%
cite_fake[-pd.isnull(cite_fake["Volume"])]["Volume"].nunique()
# Out:
# 143

# %%
cite_fake[-pd.isnull(cite_fake["Proceeding"])]["Proceeding"].nunique()
# Out:
# 238

# %%
cite_fake.groupby(["Type","Conference Type","Source title"]).count()
# Out:
#                                                                                   TitleID  \
# Type       Conference Type    Source title
# Conference Expert Group       Proceedings of SPIE - The International Society...      135
#            Regular Conference Proceedings of the ASME Design Engineering Tech...      129
#                               Proceedings of the International Telemetering C...      126
#            Symposium          Optics InfoBase Conference Papers                       116
#            Workshop           ASEE Annual Conference and Exposition, Conferen...      132
#
#                                                                                   Authors  \
# Type       Conference Type    Source title
# Conference Expert Group       Proceedings of SPIE - The International Society...      135
#            Regular Conference Proceedings of the ASME Design Engineering Tech...      129
# ...
